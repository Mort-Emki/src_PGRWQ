# %%
import importlib
import analyze_e_values as analyzer
importlib.reload(analyzer)
# Out:
# <module 'analyze_e_values' from 'd:\\PGRWQ\\PGRWQI\\debug_tools\\analyze_e_values.py'>

# %%
# 2. 验证输入文件
E_value_path = "D:\\PGRWQ\\data\\flow_results\\E_values_lstm_v2_0418\\E_0_TN.csv"
comid_list_path = "D:\\PGRWQ\\data\\flow_results\\comid_list_head_lstm_v2_0418.npy"
output_path = "D:\\PGRWQ\\data\\flow_results\\output_results_e_values_analyze"

errors = analyzer.validate_inputs(E_value_path, comid_list_path)
if errors:
    for error in errors:
        print(f"错误: {error}")
else:
    # 3. 分析E值
    results = analyzer.analyze_e_values( E_value_path, comid_list_path)
    
    # 4. 打印结果
    analyzer.print_results(results)
    
    # 5. 创建可视化图表
    analyzer.create_visualizations(E_value_path, comid_list_path, output_path)
    
    # 显示所有图表
    import matplotlib.pyplot as plt
    plt.show()
# Out:
# 正在分析E值文件: D:\PGRWQ\data\flow_results\E_values_lstm_v2_0418\E_0_TN.csv
# 头部河段文件: D:\PGRWQ\data\flow_results\comid_list_head_lstm_v2_0418.npy
# E值文件包含 11207443 条记录, 6581 个不同的COMID
# 头部河段文件包含 136 个COMID
#
# ===== E值分析结果 =====
# 总记录数: 11207443
# 总河段数: 6581
#
# 训练河段 (头部河段):
#   河段数: 136
#   记录数: 231608
#   负值记录: 4914 (2.12%)
#   NaN记录: 0 (0.00%)
#   Inf记录: 0 (0.00%)
#   值域范围: [-1.2846, 18.4875]
#   均值: 3.0168, 中位数: 2.1959
#   标准差: 2.6776
#
# 非训练河段:
#   河段数: 6445
#   记录数: 10975835
#   负值记录: 231651 (2.11%)
#   NaN记录: 0 (0.00%)
#   Inf记录: 0 (0.00%)
#   值域范围: [-5.1023, 20.3406]
#   均值: 3.8782, 中位数: 2.8557
#   标准差: 3.2504
#
# 极端负E值分布:
#   |  阈值  | 训练河段 | 非训练河段 |
#   |--------|----------|------------|
#   | < -100 |        0 |          0 |
#   | <  -50 |        0 |          0 |
#   | <  -20 |        0 |          0 |
#   | <  -10 |        0 |          0 |
#   | <   -5 |        0 |          1 |
#   | <   -1 |      123 |      39295 |
#
# 负值比例最高的训练河段 (前10个):
# ...

# %%
analyzer.analyze_comid_e_values(E_value_path, 43049975, output_path,start_date='2022-11-01', end_date='2023-8-31')
# Out:
# 正在分析COMID 43049975的E值...
#
# ===== COMID 43049975 E值分析结果 =====
# 总记录数: 1703
# 负值记录: 263 (15.44%)
# NaN记录: 0
# Inf记录: 0
# 值域范围: [-0.1043, 2.1799]
# 均值: 0.7174, 中位数: 0.6268
# 标准差: 0.5177
# 已保存E值时间序列图: D:\PGRWQ\data\flow_results\output_results_e_values_analyze\comid_43049975_e_values_20221101_to_20230831_20250418_164101.png
# d:\PGRWQ\PGRWQI\debug_tools\analyze_e_values.py:629: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comid_data['Date'] = pd.to_datetime(comid_data['Date'])
# {'comid': '43049975',
#  'total_records': 1703,
#  'neg_records': 263,
#  'neg_percentage': 15.443335290663535,
#  'nan_records': 0,
#  'inf_records': 0,
#  'stats': {'min': -0.1042948961257934,
#   'max': 2.179878234863281,
#   'mean': 0.7173925139101827,
# ...
